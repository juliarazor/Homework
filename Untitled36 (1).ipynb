# %% [markdown]
# Задание 1

# %%
import pandas as pd

# %%
def rating(rank):
        if rank >=4.5:
            return ('высокий рейтинг')
        elif rank >2.0:
            return ('средний рейтинг')
        return 'низкий рейтинг'

# %%
ratings = pd.read_csv('ratings.csv')

# %%
ratings['class'] = ratings['rating'].apply(rating)
ratings.head(30)
# Out:
#     userId  movieId  rating   timestamp            class
# 0        1       31     2.5  1260759144  средний рейтинг
# 1        1     1029     3.0  1260759179  средний рейтинг
# 2        1     1061     3.0  1260759182  средний рейтинг
# 3        1     1129     2.0  1260759185   низкий рейтинг
# 4        1     1172     4.0  1260759205  средний рейтинг
# 5        1     1263     2.0  1260759151   низкий рейтинг
# 6        1     1287     2.0  1260759187   низкий рейтинг
# 7        1     1293     2.0  1260759148   низкий рейтинг
# 8        1     1339     3.5  1260759125  средний рейтинг
# 9        1     1343     2.0  1260759131   низкий рейтинг
# 10       1     1371     2.5  1260759135  средний рейтинг
# 11       1     1405     1.0  1260759203   низкий рейтинг
# 12       1     1953     4.0  1260759191  средний рейтинг
# 13       1     2105     4.0  1260759139  средний рейтинг
# 14       1     2150     3.0  1260759194  средний рейтинг
# ...

# %% [markdown]
# Задание 2

# %%
key = pd.read_csv('keywords.csv')
key.head()
# Out:
#          keyword     shows
# 0             вк  64292779
# 1  одноклассники  63810309
# 2          порно  41747114
# 3           ютуб  39995567
# 4      вконтакте  21014195

# %%
geo_base = {
     'Центр': ['москва', 'тула', 'ярославль'],
     'Северо-Запад': ['петербург', 'псков', 'мурманск'],
     'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск'],
    }

# %%
def city_list(row):
    for key,value in geo_base.items():
        for i in value:
            if i in row['keyword']:
                return key

# %%
key['region']=key.apply(city_list,axis=1)

# %%
key['region'] = key['region'].fillna('undentified')
key.head(40)
# Out:
#                           keyword     shows       region
# 0                              вк  64292779  undentified
# 1                   одноклассники  63810309  undentified
# 2                           порно  41747114  undentified
# 3                            ютуб  39995567  undentified
# 4                       вконтакте  21014195  undentified
# 5      одноклассники моя страница  19976138  undentified
# 6                            майл  15144673  undentified
# 7                           авито  14786593  undentified
# 8                      переводчик  14453469  undentified
# 9                          яндекс  13344734  undentified
# 10                сбербанк онлайн  10725673  undentified
# 11                           mail   7687204  undentified
# 12                           игры   6075762  undentified
# 13                        youtube   5729958  undentified
# 14         вконтакте моя страница   5971451  undentified
# ...

# %%
key[(key['region']== 'Северо-Запад')].head()
# Out:
#                                                 keyword   shows        region
# 370                            авито ру санкт петербург  425134  Северо-Запад
# 564                           погода в санкт петербурге  292489  Северо-Запад
# 1236                               банк санкт петербург  174375  Северо-Запад
# 1346                                    санкт петербург  144232  Северо-Запад
# 2121  электронный дневник санкт петербургского образ...   94835  Северо-Запад

# %%
key[(key['region']== 'Центр')].head()
# Out:
#                keyword   shows region
# 127       авито москва  979292  Центр
# 849    авито ярославль  209581  Центр
# 1259            москва  153050  Центр
# 1396   гисметео москва  140279  Центр
# 1482  госуслуги москва  133061  Центр

# %%
key[(key['region']== 'Дальний Восток')].head()
# Out:
#                   keyword   shows          region
# 1063  фарпост владивосток  176951  Дальний Восток
# 2175       дром хабаровск   98361  Дальний Восток
# 3206     дром владивосток   73084  Дальний Восток
# 3275   100 сп владивосток   76418  Дальний Восток
# 3687      авито хабаровск   63736  Дальний Восток
